# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Get the nearest city using the citipy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Loop through all the cities in the list.
for i, city in enumerate(cities):
#     print("city data line 12")
#     print(city_data)

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]
#          # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')       
       # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                         "Country": city_country,
                         "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})
#                           "Country" : city_weather["sys"]["country"]
        
#         print(this_city_data)
        #city_data.append({"record_count": record_count})
#         city_data.append(this_city_data)
#         print("city data line 53 ")
#         print(city_data)

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | east london
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | hami
# Processing Record 5 of Set 1 | sao joao da barra
# Processing Record 6 of Set 1 | pisco
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | balaci
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | nishihara
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | yatou
# Processing Record 13 of Set 1 | cockburn town
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | iqaluit
# Processing Record 19 of Set 1 | esperance
# Processing Record 20 of Set 1 | longyearbyen
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | georgetown
# Processing Record 23 of Set 1 | batagay-alyta
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | mosalsk
# Processing Record 27 of Set 1 | batemans bay
# Processing Record 28 of Set 1 | severo-kurilsk
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | tiksi
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | quzhou
# Processing Record 34 of Set 1 | cidreira
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | berlevag
# Processing Record 38 of Set 1 | belaya gora
# Processing Record 39 of Set 1 | kavaratti
# Processing Record 40 of Set 1 | souillac
# Processing Record 41 of Set 1 | puerto narino
# Processing Record 42 of Set 1 | tessalit
# Processing Record 43 of Set 1 | neiafu
# Processing Record 44 of Set 1 | muros
# Processing Record 45 of Set 1 | kismayo
# Processing Record 46 of Set 1 | laguna
# Processing Record 47 of Set 1 | tocopilla
# Processing Record 48 of Set 1 | fortuna
# Processing Record 49 of Set 1 | namatanai
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | cayenne
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | varhaug
# Processing Record 5 of Set 2 | sabang
# Processing Record 6 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 7 of Set 2 | san patricio
# Processing Record 8 of Set 2 | jagdalpur
# Processing Record 9 of Set 2 | semnan
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | sulangan
# Processing Record 15 of Set 2 | zhezkazgan
# Processing Record 16 of Set 2 | filadelfia
# Processing Record 17 of Set 2 | arlit
# Processing Record 18 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 19 of Set 2 | touros
# Processing Record 20 of Set 2 | aksha
# Processing Record 21 of Set 2 | mansa
# Processing Record 22 of Set 2 | hay river
# Processing Record 23 of Set 2 | bethel
# Processing Record 24 of Set 2 | verkhniy mamon
# Processing Record 25 of Set 2 | meulaboh
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | lagoa
# Processing Record 28 of Set 2 | coffs harbour
# Processing Record 29 of Set 2 | bantry
# Processing Record 30 of Set 2 | victoria
# Processing Record 31 of Set 2 | maniitsoq
# Processing Record 32 of Set 2 | sola
# Processing Record 33 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 2 | tabuk
# Processing Record 36 of Set 2 | vila velha
# Processing Record 37 of Set 2 | tilichiki
# Processing Record 38 of Set 2 | weilburg
# Processing Record 39 of Set 2 | shelburne
# Processing Record 40 of Set 2 | kangaatsiaq
# Processing Record 41 of Set 2 | sukhobezvodnoye
# Processing Record 42 of Set 2 | cape town
# Processing Record 43 of Set 2 | the pas
# Processing Record 44 of Set 2 | prado
# Processing Record 45 of Set 2 | ende
# Processing Record 46 of Set 2 | narrabri
# Processing Record 47 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 2 | hamilton
# Processing Record 49 of Set 2 | walvis bay
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | aklavik
# Processing Record 2 of Set 3 | luderitz
# Processing Record 3 of Set 3 | slave lake
# Processing Record 4 of Set 3 | madang
# Processing Record 5 of Set 3 | mataura
# Processing Record 6 of Set 3 | fernley
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | zacoalco
# City not found. Skipping...
# Processing Record 9 of Set 3 | kenora
# Processing Record 10 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 3 | asau
# Processing Record 12 of Set 3 | coihaique
# Processing Record 13 of Set 3 | atasu
# Processing Record 14 of Set 3 | sarkand
# Processing Record 15 of Set 3 | volnovakha
# Processing Record 16 of Set 3 | itarema
# Processing Record 17 of Set 3 | sakete
# Processing Record 18 of Set 3 | new norfolk
# Processing Record 19 of Set 3 | chokurdakh
# Processing Record 20 of Set 3 | rio grande
# Processing Record 21 of Set 3 | kodiak
# Processing Record 22 of Set 3 | rio gallegos
# Processing Record 23 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 3 | port elizabeth
# Processing Record 25 of Set 3 | north bend
# Processing Record 26 of Set 3 | santa vitoria do palmar
# Processing Record 27 of Set 3 | nam som
# Processing Record 28 of Set 3 | khovu-aksy
# Processing Record 29 of Set 3 | betki
# City not found. Skipping...
# Processing Record 30 of Set 3 | muroto
# Processing Record 31 of Set 3 | xining
# Processing Record 32 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 3 | tuktoyaktuk
# Processing Record 34 of Set 3 | grand gaube
# Processing Record 35 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 3 | tual
# Processing Record 37 of Set 3 | clyde river
# Processing Record 38 of Set 3 | sahrak
# City not found. Skipping...
# Processing Record 39 of Set 3 | ewa beach
# Processing Record 40 of Set 3 | ribeira grande
# Processing Record 41 of Set 3 | holme
# Processing Record 42 of Set 3 | atar
# Processing Record 43 of Set 3 | paamiut
# Processing Record 44 of Set 3 | ostrovnoy
# Processing Record 45 of Set 3 | coahuayana
# Processing Record 46 of Set 3 | san lawrenz
# Processing Record 47 of Set 3 | omboue
# Processing Record 48 of Set 3 | waingapu
# Processing Record 49 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 3 | acin
# City not found. Skipping...
# Processing Record 1 of Set 4 | lakota
# Processing Record 2 of Set 4 | gondanglegi
# Processing Record 3 of Set 4 | dingle
# Processing Record 4 of Set 4 | hilo
# Processing Record 5 of Set 4 | kloulklubed
# Processing Record 6 of Set 4 | ambilobe
# Processing Record 7 of Set 4 | faanui
# Processing Record 8 of Set 4 | noyabrsk
# Processing Record 9 of Set 4 | mar del plata
# Processing Record 10 of Set 4 | sitio novo do tocantins
# Processing Record 11 of Set 4 | saint-philippe
# Processing Record 12 of Set 4 | carballo
# Processing Record 13 of Set 4 | skjervoy
# Processing Record 14 of Set 4 | deh rawud
# City not found. Skipping...
# Processing Record 15 of Set 4 | palmer
# Processing Record 16 of Set 4 | de aar
# Processing Record 17 of Set 4 | langarud
# Processing Record 18 of Set 4 | isangel
# Processing Record 19 of Set 4 | cabo san lucas
# Processing Record 20 of Set 4 | kaitangata
# Processing Record 21 of Set 4 | dzhebariki-khaya
# Processing Record 22 of Set 4 | tasiilaq
# Processing Record 23 of Set 4 | saskylakh
# Processing Record 24 of Set 4 | tautira
# Processing Record 25 of Set 4 | katherine
# Processing Record 26 of Set 4 | mount isa
# Processing Record 27 of Set 4 | rochester
# Processing Record 28 of Set 4 | ixtapa
# Processing Record 29 of Set 4 | upernavik
# Processing Record 30 of Set 4 | saint george
# Processing Record 31 of Set 4 | birin
# Processing Record 32 of Set 4 | mareeba
# Processing Record 33 of Set 4 | cap malheureux
# Processing Record 34 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 4 | gemena
# Processing Record 36 of Set 4 | lompoc
# Processing Record 37 of Set 4 | san cristobal
# Processing Record 38 of Set 4 | deputatskiy
# Processing Record 39 of Set 4 | freeport
# Processing Record 40 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 4 | catuday
# Processing Record 42 of Set 4 | sitka
# Processing Record 43 of Set 4 | erenhot
# Processing Record 44 of Set 4 | vincennes
# Processing Record 45 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 4 | sorland
# Processing Record 47 of Set 4 | vao
# Processing Record 48 of Set 4 | neuquen
# Processing Record 49 of Set 4 | sao borja
# Processing Record 50 of Set 4 | kontagora
# Processing Record 1 of Set 5 | ouango
# Processing Record 2 of Set 5 | saint-pierre
# Processing Record 3 of Set 5 | lebu
# Processing Record 4 of Set 5 | kaeng khlo
# City not found. Skipping...
# Processing Record 5 of Set 5 | pevek
# Processing Record 6 of Set 5 | baijiantan
# Processing Record 7 of Set 5 | ilinskiy
# Processing Record 8 of Set 5 | ambagarh chauki
# Processing Record 9 of Set 5 | warwick
# Processing Record 10 of Set 5 | vieques
# Processing Record 11 of Set 5 | arraial do cabo
# Processing Record 12 of Set 5 | norman wells
# Processing Record 13 of Set 5 | codrington
# Processing Record 14 of Set 5 | saldanha
# Processing Record 15 of Set 5 | banda aceh
# Processing Record 16 of Set 5 | los llanos de aridane
# Processing Record 17 of Set 5 | verkhoyansk
# Processing Record 18 of Set 5 | ipubi
# Processing Record 19 of Set 5 | brae
# Processing Record 20 of Set 5 | kavieng
# Processing Record 21 of Set 5 | lima
# Processing Record 22 of Set 5 | aykhal
# Processing Record 23 of Set 5 | jaguariaiva
# Processing Record 24 of Set 5 | chifeng
# Processing Record 25 of Set 5 | dubai
# Processing Record 26 of Set 5 | ketchikan
# Processing Record 27 of Set 5 | vardo
# Processing Record 28 of Set 5 | tolga
# Processing Record 29 of Set 5 | husavik
# Processing Record 30 of Set 5 | tyup
# Processing Record 31 of Set 5 | shubarkuduk
# Processing Record 32 of Set 5 | lodwar
# Processing Record 33 of Set 5 | port hardy
# Processing Record 34 of Set 5 | beringovskiy
# Processing Record 35 of Set 5 | kadoma
# Processing Record 36 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 5 | lavrentiya
# Processing Record 38 of Set 5 | new iberia
# Processing Record 39 of Set 5 | sinjar
# Processing Record 40 of Set 5 | mogadishu
# Processing Record 41 of Set 5 | namibe
# Processing Record 42 of Set 5 | coos bay
# Processing Record 43 of Set 5 | dunedin
# Processing Record 44 of Set 5 | salisbury
# Processing Record 45 of Set 5 | hithadhoo
# Processing Record 46 of Set 5 | bluefield
# Processing Record 47 of Set 5 | sao sebastiao
# Processing Record 48 of Set 5 | castro
# Processing Record 49 of Set 5 | port lincoln
# Processing Record 50 of Set 5 | panaba
# Processing Record 1 of Set 6 | margate
# Processing Record 2 of Set 6 | caravelas
# Processing Record 3 of Set 6 | khor
# Processing Record 4 of Set 6 | redcar
# Processing Record 5 of Set 6 | hobart
# Processing Record 6 of Set 6 | aras
# Processing Record 7 of Set 6 | broome
# Processing Record 8 of Set 6 | tura
# Processing Record 9 of Set 6 | dangtu
# Processing Record 10 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 6 | butaritari
# Processing Record 12 of Set 6 | kruisfontein
# Processing Record 13 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 6 | rognan
# Processing Record 15 of Set 6 | qaqortoq
# Processing Record 16 of Set 6 | oranjemund
# Processing Record 17 of Set 6 | henties bay
# Processing Record 18 of Set 6 | yamada
# Processing Record 19 of Set 6 | bucarasica
# Processing Record 20 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 6 | vila franca do campo
# Processing Record 22 of Set 6 | tiznit
# Processing Record 23 of Set 6 | sidi bin nur
# Processing Record 24 of Set 6 | adrar
# Processing Record 25 of Set 6 | vanimo
# Processing Record 26 of Set 6 | thompson
# Processing Record 27 of Set 6 | coquimbo
# Processing Record 28 of Set 6 | nieuw amsterdam
# Processing Record 29 of Set 6 | maarianhamina
# Processing Record 30 of Set 6 | samarai
# Processing Record 31 of Set 6 | lata
# Processing Record 32 of Set 6 | broken hill
# Processing Record 33 of Set 6 | gubkinskiy
# Processing Record 34 of Set 6 | sechura
# Processing Record 35 of Set 6 | boa vista
# Processing Record 36 of Set 6 | mangai
# Processing Record 37 of Set 6 | bemidji
# Processing Record 38 of Set 6 | skibbereen
# Processing Record 39 of Set 6 | safaga
# Processing Record 40 of Set 6 | cherskiy
# Processing Record 41 of Set 6 | karachev
# Processing Record 42 of Set 6 | bonthe
# Processing Record 43 of Set 6 | ust-maya
# Processing Record 44 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 6 | at-bashi
# Processing Record 46 of Set 6 | sao filipe
# Processing Record 47 of Set 6 | sao jose da coroa grande
# Processing Record 48 of Set 6 | camacha
# Processing Record 49 of Set 6 | campos belos
# Processing Record 50 of Set 6 | bardsir
# Processing Record 1 of Set 7 | rauma
# Processing Record 2 of Set 7 | urumita
# Processing Record 3 of Set 7 | auki
# Processing Record 4 of Set 7 | gongzhuling
# Processing Record 5 of Set 7 | maneadero
# Processing Record 6 of Set 7 | jipapad
# Processing Record 7 of Set 7 | bucerias
# Processing Record 8 of Set 7 | nabire
# Processing Record 9 of Set 7 | amuntai
# Processing Record 10 of Set 7 | leningradskiy
# Processing Record 11 of Set 7 | labuhan
# Processing Record 12 of Set 7 | komsomolskiy
# Processing Record 13 of Set 7 | saint anthony
# Processing Record 14 of Set 7 | karatau
# Processing Record 15 of Set 7 | yar-sale
# Processing Record 16 of Set 7 | inhambane
# Processing Record 17 of Set 7 | lorengau
# Processing Record 18 of Set 7 | clinton
# Processing Record 19 of Set 7 | conde
# Processing Record 20 of Set 7 | camana
# Processing Record 21 of Set 7 | doha
# Processing Record 22 of Set 7 | kiama
# Processing Record 23 of Set 7 | buala
# Processing Record 24 of Set 7 | college
# Processing Record 25 of Set 7 | marsh harbour
# Processing Record 26 of Set 7 | ushtobe
# Processing Record 27 of Set 7 | carnarvon
# Processing Record 28 of Set 7 | nyurba
# Processing Record 29 of Set 7 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 30 of Set 7 | eureka
# Processing Record 31 of Set 7 | padang
# Processing Record 32 of Set 7 | grants
# Processing Record 33 of Set 7 | naze
# Processing Record 34 of Set 7 | pangai
# Processing Record 35 of Set 7 | marfino
# Processing Record 36 of Set 7 | porto novo
# Processing Record 37 of Set 7 | turukhansk
# Processing Record 38 of Set 7 | gaya
# Processing Record 39 of Set 7 | port blair
# Processing Record 40 of Set 7 | alice springs
# Processing Record 41 of Set 7 | anadyr
# Processing Record 42 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 7 | ponta do sol
# Processing Record 44 of Set 7 | bonavista
# Processing Record 45 of Set 7 | svrljig
# Processing Record 46 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 47 of Set 7 | malinovskiy
# Processing Record 48 of Set 7 | maine-soroa
# Processing Record 49 of Set 7 | haimen
# Processing Record 50 of Set 7 | weihai
# Processing Record 1 of Set 8 | sungaipenuh
# Processing Record 2 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 3 of Set 8 | kushiro
# Processing Record 4 of Set 8 | hollins
# Processing Record 5 of Set 8 | kitimat
# Processing Record 6 of Set 8 | erzurum
# Processing Record 7 of Set 8 | huarmey
# Processing Record 8 of Set 8 | krasnyy yar
# Processing Record 9 of Set 8 | bathsheba
# Processing Record 10 of Set 8 | comodoro rivadavia
# Processing Record 11 of Set 8 | dongfeng
# Processing Record 12 of Set 8 | albury
# Processing Record 13 of Set 8 | moron
# Processing Record 14 of Set 8 | basco
# Processing Record 15 of Set 8 | ales
# Processing Record 16 of Set 8 | harper
# Processing Record 17 of Set 8 | trincomalee
# Processing Record 18 of Set 8 | kirakira
# Processing Record 19 of Set 8 | gizo
# Processing Record 20 of Set 8 | flin flon
# Processing Record 21 of Set 8 | wloszczowa
# Processing Record 22 of Set 8 | yakeshi
# Processing Record 23 of Set 8 | presidente medici
# Processing Record 24 of Set 8 | beloha
# Processing Record 25 of Set 8 | katsuura
# Processing Record 26 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 8 | nome
# Processing Record 28 of Set 8 | kpalime
# Processing Record 29 of Set 8 | mizdah
# Processing Record 30 of Set 8 | tukrah
# Processing Record 31 of Set 8 | banyo
# Processing Record 32 of Set 8 | sitamau
# Processing Record 33 of Set 8 | sturgeon falls
# Processing Record 34 of Set 8 | lamu
# Processing Record 35 of Set 8 | hasaki
# Processing Record 36 of Set 8 | cukai
# Processing Record 37 of Set 8 | moville
# Processing Record 38 of Set 8 | vila
# Processing Record 39 of Set 8 | blankenberge
# Processing Record 40 of Set 8 | macomb
# Processing Record 41 of Set 8 | hambantota
# Processing Record 42 of Set 8 | hukuntsi
# Processing Record 43 of Set 8 | belomorsk
# Processing Record 44 of Set 8 | quatre cocos
# Processing Record 45 of Set 8 | sindand
# City not found. Skipping...
# Processing Record 46 of Set 8 | natal
# Processing Record 47 of Set 8 | geraldton
# Processing Record 48 of Set 8 | tortoli
# Processing Record 49 of Set 8 | beian
# Processing Record 50 of Set 8 | airai
# Processing Record 1 of Set 9 | dudinka
# Processing Record 2 of Set 9 | promysla
# City not found. Skipping...
# Processing Record 3 of Set 9 | mana
# Processing Record 4 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 9 | ahipara
# Processing Record 6 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 9 | fez
# Processing Record 8 of Set 9 | jalu
# Processing Record 9 of Set 9 | milingimbi
# City not found. Skipping...
# Processing Record 10 of Set 9 | egvekinot
# Processing Record 11 of Set 9 | novyy urengoy
# Processing Record 12 of Set 9 | provideniya
# Processing Record 13 of Set 9 | eston
# Processing Record 14 of Set 9 | kisangani
# Processing Record 15 of Set 9 | piranshahr
# Processing Record 16 of Set 9 | nyimba
# Processing Record 17 of Set 9 | pativilca
# Processing Record 18 of Set 9 | ajdabiya
# Processing Record 19 of Set 9 | talisayan
# Processing Record 20 of Set 9 | plessisville
# Processing Record 21 of Set 9 | tuatapere
# Processing Record 22 of Set 9 | fayaoue
# Processing Record 23 of Set 9 | krasavino
# Processing Record 24 of Set 9 | harnosand
# Processing Record 25 of Set 9 | nouadhibou
# Processing Record 26 of Set 9 | wonthaggi
# Processing Record 27 of Set 9 | marsa matruh
# Processing Record 28 of Set 9 | lasa
# Processing Record 29 of Set 9 | havre-saint-pierre
# Processing Record 30 of Set 9 | yuli
# Processing Record 31 of Set 9 | leogane
# Processing Record 32 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 9 | nehe
# Processing Record 34 of Set 9 | narsaq
# Processing Record 35 of Set 9 | boizenburg
# Processing Record 36 of Set 9 | urucui
# Processing Record 37 of Set 9 | la ronge
# Processing Record 38 of Set 9 | novikovo
# Processing Record 39 of Set 9 | bubaque
# Processing Record 40 of Set 9 | paciran
# Processing Record 41 of Set 9 | yashkul
# Processing Record 42 of Set 9 | middlebury
# Processing Record 43 of Set 9 | amazar
# Processing Record 44 of Set 9 | sept-iles
# Processing Record 45 of Set 9 | balauseri
# Processing Record 46 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 9 | pestretsy
# Processing Record 48 of Set 9 | severomorsk
# Processing Record 49 of Set 9 | ust-kuyga
# Processing Record 50 of Set 9 | pacific grove
# Processing Record 1 of Set 10 | bud
# Processing Record 2 of Set 10 | fort nelson
# Processing Record 3 of Set 10 | west bay
# Processing Record 4 of Set 10 | gasa
# Processing Record 5 of Set 10 | champerico
# Processing Record 6 of Set 10 | bereda
# Processing Record 7 of Set 10 | conceicao do araguaia
# Processing Record 8 of Set 10 | kutum
# Processing Record 9 of Set 10 | sal rei
# Processing Record 10 of Set 10 | baruun-urt
# Processing Record 11 of Set 10 | teahupoo
# Processing Record 12 of Set 10 | hofn
# Processing Record 13 of Set 10 | krasnoselkup
# Processing Record 14 of Set 10 | grindavik
# Processing Record 15 of Set 10 | sabha
# Processing Record 16 of Set 10 | srednekolymsk
# Processing Record 17 of Set 10 | mulbagal
# Processing Record 18 of Set 10 | cabedelo
# Processing Record 19 of Set 10 | lerwick
# Processing Record 20 of Set 10 | petropavl
# Processing Record 21 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 10 | tigzirt
# Processing Record 23 of Set 10 | sangmelima
# Processing Record 24 of Set 10 | sibolga
# Processing Record 25 of Set 10 | paita
# Processing Record 26 of Set 10 | alofi
# Processing Record 27 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 28 of Set 10 | nalut
# Processing Record 29 of Set 10 | vestmanna
# Processing Record 30 of Set 10 | pachino
# Processing Record 31 of Set 10 | tetouan
# Processing Record 32 of Set 10 | inverell
# Processing Record 33 of Set 10 | canutama
# Processing Record 34 of Set 10 | charters towers
# Processing Record 35 of Set 10 | bokoro
# Processing Record 36 of Set 10 | klaksvik
# Processing Record 37 of Set 10 | maceio
# Processing Record 38 of Set 10 | yulara
# Processing Record 39 of Set 10 | gambo
# Processing Record 40 of Set 10 | brewster
# Processing Record 41 of Set 10 | yumen
# Processing Record 42 of Set 10 | maldonado
# Processing Record 43 of Set 10 | port-cartier
# Processing Record 44 of Set 10 | haileybury
# Processing Record 45 of Set 10 | torbay
# Processing Record 46 of Set 10 | mackay
# Processing Record 47 of Set 10 | matiri
# Processing Record 48 of Set 10 | acapulco
# Processing Record 49 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 1 of Set 11 | yungay
# Processing Record 2 of Set 11 | nouakchott
# Processing Record 3 of Set 11 | general cepeda
# Processing Record 4 of Set 11 | stanari
# Processing Record 5 of Set 11 | poum
# Processing Record 6 of Set 11 | yaring
# Processing Record 7 of Set 11 | mehamn
# Processing Record 8 of Set 11 | lesnoy
# Processing Record 9 of Set 11 | pionerskiy
# Processing Record 10 of Set 11 | twentynine palms
# Processing Record 11 of Set 11 | belmonte
# Processing Record 12 of Set 11 | kugesi
# Processing Record 13 of Set 11 | talcahuano
# Processing Record 14 of Set 11 | manokwari
# Processing Record 15 of Set 11 | bandarbeyla
# Processing Record 16 of Set 11 | swan hill
# Processing Record 17 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 11 | lianzhou
# Processing Record 19 of Set 11 | solwezi
# Processing Record 20 of Set 11 | estelle
# Processing Record 21 of Set 11 | pahrump
# Processing Record 22 of Set 11 | portland
# Processing Record 23 of Set 11 | ancud
# Processing Record 24 of Set 11 | svetlyy yar
# Processing Record 25 of Set 11 | nawa
# Processing Record 26 of Set 11 | mapiripan
# Processing Record 27 of Set 11 | razole
# Processing Record 28 of Set 11 | samoylovka
# Processing Record 29 of Set 11 | ustka
# Processing Record 30 of Set 11 | chahuites
# Processing Record 31 of Set 11 | oskaloosa
# Processing Record 32 of Set 11 | nanortalik
# Processing Record 33 of Set 11 | sungairaya
# Processing Record 34 of Set 11 | yei
# Processing Record 35 of Set 11 | yining
# Processing Record 36 of Set 11 | nantucket
# Processing Record 37 of Set 11 | pochutla
# Processing Record 38 of Set 11 | tokur
# Processing Record 39 of Set 11 | tezu
# Processing Record 40 of Set 11 | salalah
# Processing Record 41 of Set 11 | inongo
# Processing Record 42 of Set 11 | dno
# Processing Record 43 of Set 11 | antalaha
# Processing Record 44 of Set 11 | araouane
# Processing Record 45 of Set 11 | manono
# Processing Record 46 of Set 11 | qinzhou
# Processing Record 47 of Set 11 | sabinas hidalgo
# Processing Record 48 of Set 11 | calamar
# Processing Record 49 of Set 11 | ereymentau
# Processing Record 50 of Set 11 | ridgecrest
# Processing Record 1 of Set 12 | vaitape
# Processing Record 2 of Set 12 | longview
# Processing Record 3 of Set 12 | kabanjahe
# Processing Record 4 of Set 12 | kalmunai
# Processing Record 5 of Set 12 | galle
# Processing Record 6 of Set 12 | bielsko-biala
# Processing Record 7 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 8 of Set 12 | zarubino
# Processing Record 9 of Set 12 | road town
# Processing Record 10 of Set 12 | khani
# Processing Record 11 of Set 12 | sinop
# Processing Record 12 of Set 12 | rawson
# Processing Record 13 of Set 12 | kiruna
# Processing Record 14 of Set 12 | jumla
# Processing Record 15 of Set 12 | idah
# Processing Record 16 of Set 12 | hobyo
# Processing Record 17 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 18 of Set 12 | kavali
# Processing Record 19 of Set 12 | nunoa
# Processing Record 20 of Set 12 | puerto escondido
# Processing Record 21 of Set 12 | ballina
# Processing Record 22 of Set 12 | abhar
# Processing Record 23 of Set 12 | ler
# Processing Record 24 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 25 of Set 12 | kenai
# Processing Record 26 of Set 12 | ugoofaaru
# Processing Record 27 of Set 12 | kyaikkami
# Processing Record 28 of Set 12 | grand-santi
# Processing Record 29 of Set 12 | kingman
# Processing Record 30 of Set 12 | axim
# Processing Record 31 of Set 12 | homer
# Processing Record 32 of Set 12 | australind
# Processing Record 33 of Set 12 | bogo
# Processing Record 34 of Set 12 | anloga
# Processing Record 35 of Set 12 | chanika
# Processing Record 36 of Set 12 | halifax
# Processing Record 37 of Set 12 | primorsk
# Processing Record 38 of Set 12 | macau
# Processing Record 39 of Set 12 | leon
# Processing Record 40 of Set 12 | san policarpo
# Processing Record 41 of Set 12 | gamba
# Processing Record 42 of Set 12 | karasjok
# Processing Record 43 of Set 12 | arona
# Processing Record 44 of Set 12 | dosso
# Processing Record 45 of Set 12 | old road
# City not found. Skipping...
# Processing Record 46 of Set 12 | te anau
# Processing Record 47 of Set 12 | elat
# Processing Record 48 of Set 12 | becerril
# Processing Record 49 of Set 12 | kupang
# Processing Record 50 of Set 12 | chapais
# Processing Record 1 of Set 13 | vinukonda
# Processing Record 2 of Set 13 | puri
# Processing Record 3 of Set 13 | veinticinco de mayo
# Processing Record 4 of Set 13 | pihuamo
# Processing Record 5 of Set 13 | dumai
# Processing Record 6 of Set 13 | kahului
# Processing Record 7 of Set 13 | ojinaga
# Processing Record 8 of Set 13 | balikpapan
# Processing Record 9 of Set 13 | san severo
# Processing Record 10 of Set 13 | mezen
# Processing Record 11 of Set 13 | dongning
# Processing Record 12 of Set 13 | memari
# Processing Record 13 of Set 13 | isla vista
# Processing Record 14 of Set 13 | garoua
# Processing Record 15 of Set 13 | tanete
# Processing Record 16 of Set 13 | kilindoni
# Processing Record 17 of Set 13 | petropavlovskoye
# Processing Record 18 of Set 13 | luang prabang
# Processing Record 19 of Set 13 | bambanglipuro
# Processing Record 20 of Set 13 | parfino
# Processing Record 21 of Set 13 | praya
# Processing Record 22 of Set 13 | honiara
# Processing Record 23 of Set 13 | doka
# Processing Record 24 of Set 13 | edd
# Processing Record 25 of Set 13 | chase
# Processing Record 26 of Set 13 | north platte
# Processing Record 27 of Set 13 | capreol
# Processing Record 28 of Set 13 | placido de castro
# Processing Record 29 of Set 13 | papasquiaro
# City not found. Skipping...
# Processing Record 30 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 31 of Set 13 | alugan
# Processing Record 32 of Set 13 | asyut
# Processing Record 33 of Set 13 | haines junction
# Processing Record 34 of Set 13 | acajutla
# Processing Record 35 of Set 13 | karatuzskoye
# Processing Record 36 of Set 13 | ilulissat
# Processing Record 37 of Set 13 | zlobin
# Processing Record 38 of Set 13 | port macquarie
# Processing Record 39 of Set 13 | grajewo
# Processing Record 40 of Set 13 | saint-francois
# Processing Record 41 of Set 13 | iskateley
# Processing Record 42 of Set 13 | lere
# Processing Record 43 of Set 13 | guarapari
# Processing Record 44 of Set 13 | ilhabela
# Processing Record 45 of Set 13 | warrnambool
# Processing Record 46 of Set 13 | kaduqli
# Processing Record 47 of Set 13 | bambous virieux
# Processing Record 48 of Set 13 | zhongxing
# Processing Record 49 of Set 13 | ipixuna
# Processing Record 50 of Set 13 | ulaanbaatar
# Processing Record 1 of Set 14 | rundu
# Processing Record 2 of Set 14 | toamasina
# Processing Record 3 of Set 14 | ust-nera
# Processing Record 4 of Set 14 | el badari
# City not found. Skipping...
# Processing Record 5 of Set 14 | coari
# Processing Record 6 of Set 14 | gari
# Processing Record 7 of Set 14 | gaoual
# Processing Record 8 of Set 14 | dwarka
# Processing Record 9 of Set 14 | salas
# Processing Record 10 of Set 14 | bossembele
# City not found. Skipping...
# Processing Record 11 of Set 14 | stykkisholmur
# Processing Record 12 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 13 of Set 14 | ningbo
# Processing Record 14 of Set 14 | sherbakul
# Processing Record 15 of Set 14 | taft
# Processing Record 16 of Set 14 | synya
# Processing Record 17 of Set 14 | pacifica
# Processing Record 18 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 14 | amod
# Processing Record 20 of Set 14 | havelock
# Processing Record 21 of Set 14 | talara
# Processing Record 22 of Set 14 | kamenka
# Processing Record 23 of Set 14 | kulhudhuffushi
# Processing Record 24 of Set 14 | yeletskiy
# City not found. Skipping...
# Processing Record 25 of Set 14 | formosa
# Processing Record 26 of Set 14 | mocuba
# Processing Record 27 of Set 14 | businga
# Processing Record 28 of Set 14 | santa isabel do rio negro
# Processing Record 29 of Set 14 | keti bandar
# Processing Record 30 of Set 14 | christchurch
# Processing Record 31 of Set 14 | port hedland
# Processing Record 32 of Set 14 | babu
# Processing Record 33 of Set 14 | nazarovo
# Processing Record 34 of Set 14 | bataipora
# Processing Record 35 of Set 14 | matara
# Processing Record 36 of Set 14 | tsybli
# Processing Record 37 of Set 14 | bhainsa
# Processing Record 38 of Set 14 | morros
# Processing Record 39 of Set 14 | hoquiam
# Processing Record 40 of Set 14 | bolshiye uki
# City not found. Skipping...
# Processing Record 41 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 42 of Set 14 | mandali
# Processing Record 43 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 14 | praia da vitoria
# Processing Record 45 of Set 14 | ambanja
# Processing Record 46 of Set 14 | rabo de peixe
# Processing Record 47 of Set 14 | khandyga
# Processing Record 48 of Set 14 | poya
# Processing Record 49 of Set 14 | igrim
# Processing Record 50 of Set 14 | yafran
# Processing Record 1 of Set 15 | imeni zhelyabova
# Processing Record 2 of Set 15 | waddan
# Processing Record 3 of Set 15 | whyalla
# Processing Record 4 of Set 15 | bima
# Processing Record 5 of Set 15 | kaoma
# Processing Record 6 of Set 15 | ondjiva
# Processing Record 7 of Set 15 | pietermaritzburg
# Processing Record 8 of Set 15 | tucuma
# Processing Record 9 of Set 15 | fairbanks
# Processing Record 10 of Set 15 | filotion
# Processing Record 11 of Set 15 | trelew
# Processing Record 12 of Set 15 | targu-lapus
# City not found. Skipping...
# Processing Record 13 of Set 15 | wenling
# Processing Record 14 of Set 15 | el espinal
# Processing Record 15 of Set 15 | rio verde de mato grosso
# Processing Record 16 of Set 15 | magadan
# Processing Record 17 of Set 15 | isetskoye
# Processing Record 18 of Set 15 | bulgan
# Processing Record 19 of Set 15 | makakilo city
# Processing Record 20 of Set 15 | nhulunbuy
# Processing Record 21 of Set 15 | boden
# Processing Record 22 of Set 15 | wote
# Processing Record 23 of Set 15 | hervey bay
# Processing Record 24 of Set 15 | georgiyevka
# Processing Record 25 of Set 15 | urucara
# Processing Record 26 of Set 15 | longkou
# Processing Record 27 of Set 15 | tiarei
# Processing Record 28 of Set 15 | ransang
# Processing Record 29 of Set 15 | sandpoint
# Processing Record 30 of Set 15 | nemuro
# Processing Record 31 of Set 15 | ryotsu
# Processing Record 32 of Set 15 | krasnoturansk
# Processing Record 33 of Set 15 | mahajanga
# Processing Record 34 of Set 15 | mutis
# Processing Record 35 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 15 | prince rupert
# Processing Record 37 of Set 15 | pankovka
# Processing Record 38 of Set 15 | nanga eboko
# Processing Record 39 of Set 15 | pokhara
# Processing Record 40 of Set 15 | daru
# Processing Record 41 of Set 15 | byumba
# Processing Record 42 of Set 15 | muyezerskiy
# Processing Record 43 of Set 15 | flagstaff
# Processing Record 44 of Set 15 | goderich
# Processing Record 45 of Set 15 | biharamulo
# Processing Record 46 of Set 15 | sabzevar
# Processing Record 47 of Set 15 | saint-leu
# Processing Record 48 of Set 15 | santa rosa
# Processing Record 49 of Set 15 | les cayes
# Processing Record 50 of Set 15 | pilar
# Processing Record 1 of Set 16 | mobile
# Processing Record 2 of Set 16 | wanaka
# Processing Record 3 of Set 16 | tabialan
# City not found. Skipping...
# Processing Record 4 of Set 16 | skalistyy
# City not found. Skipping...
# Processing Record 5 of Set 16 | siirt
# Processing Record 6 of Set 16 | wuwei
# Processing Record 7 of Set 16 | sazonovo
# Processing Record 8 of Set 16 | oxford
# Processing Record 9 of Set 16 | najran
# Processing Record 10 of Set 16 | kailua
# Processing Record 11 of Set 16 | paringao
# Processing Record 12 of Set 16 | novobelokatay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Atuona      PF  -9.8000 -139.0333     77.36        75
# 1        East London      ZA -33.0153   27.9116     67.14        88
# 2           Khatanga      RU  71.9667  102.5000    -26.30       100
# 3               Hami      CN  42.8000   93.4500     28.76        50
# 4  Sao Joao Da Barra      BR -21.6403  -41.0511     73.49        89
#
#    Cloudiness  Wind Speed   Current Description
# 0          21        9.57            few clouds
# 1          40        9.22            light rain
# 2          74        5.30         broken clouds
# 3          76        2.55         broken clouds
# 4         100       11.72  heavy intensity rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
